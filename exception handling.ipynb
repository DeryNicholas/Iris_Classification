# %% [markdown]
# print(x)

# %% [markdown]
# ### Handling Errors
# python uses the keywords try and except to handle errors. this takes the form of two code blocks

# %%
try:
    # some code that you want too run
except KeyError: 
    # what you want to happen instead
    # if an error of this type is raised
finally # block lets you execute code, regardless of the result of the try- and except blocks.

# %%
try:
  print(x)
except:
  print("An exception occurred")
# Out:
# An exception occurred

# %%
#x = ['Kobbie']
# Print one message if the try block raises a NameError and another for other errors
try:
  print(x)
  1/0
except NameError:
  print("Variable x is not defined")
except:
  print("Something else went wrong")
# Out:
# ['Kobbie']
# Something else went wrong

# %%
# You can use the else keyword to define a block of code to be executed if no errors were raised:
try:
  print("Hello")
except:
  print("Something went wrong")
else:
  print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
try:
  print(x)
except:
  print("Something went wrong")
finally:
  print("The 'try except' is finished")

# %%
try:
  f = open("demofile.txt")
  try:
    f.write("Lorum Ipsum")
  except:
    print("Something went wrong when writing to the file")
  finally:
    f.close()
except:
  print("Something went wrong when opening the file")

# %% [markdown]
# ### Raise an exception
# As a Python developer you can choose to throw an exception if a condition occurs.
#
# To throw (or raise) an exception, use the raise keyword.

# %%
x = -1

if x < 0:
  raise Exception("Sorry, no numbers below zero")

# %%
#Raise a TypeError if x is not an integer:
x = "hello"

if not type(x) is int:
  raise TypeError("Only integers are allowed")

# %%
try:
    with open('my_file.txt','r') as f:
        whats_inside=f.read()
        print(whats_inside)
except FileNotFoundError:
    print('This file cannot be found')

# %%
def divide(num1,num2):
    try:
        if num1%num2==0:  
                return f'{num1} is divisible by {num2}'
        else:
            return f'{num1} is not divisible by {num2}'    
    except TypeError:
        print("Please enter only numbers")
    else:
        print(f"Yes!,{num1} can be divided by {num2}")
    finally:
        print("Continue...\n Try with other numbers")
divide(8,3m)

# %%
import os
my_directory=os.getcwd()
print(my_directory)
# Out:
# d:\Desktop\PYTHON PRACTICE

# %%
os.listdir(my_directory)

# %%
#changing the current working directory
os.chdir('d:\Desktop\PYTHON PRACTICE\Nicks')
